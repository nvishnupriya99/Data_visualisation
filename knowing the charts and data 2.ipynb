# %%
# Step 1: Import Necessary Libraries
import pandas as pd
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import nltk

# Download stopwords from NLTK
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\avais\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Step 2: Load the mpox dataset
df = pd.read_csv('reddit_monkeypox.csv')

# Display the first few rows of the dataset
df.head()
# Out:
#                                                title  score      id  \
# 0   Monkeypox may be on its way to a school near you    101  wtgjsb
# 1                       Purpose of Home Disinfection     29  wt923l
# 2  Lack of ‘high quality’ clinical guidelines for...     45  wsu8pe
# 3  California issues monkeypox quarantine guidelines    135  wsn73d
# 4  EU backs changing monkeypox vaccine injection ...      2  wsn2my
#
#                                                  url  comms_num     created  \
# 0  https://thehill.com/opinion/healthcare/3607622...         33  1661026996
# 1  https://www.cdc.gov/poxvirus/monkeypox/specifi...         18  1661007372
# 2  https://thehill.com/changing-america/well-bein...          2  1660957502
# 3  https://www.kron4.com/monkeypox/california-iss...         31  1660938749
# 4  https://www.reuters.com/business/healthcare-ph...          4  1660938429
#
#   body year-month-day hour-min-sec
# 0  NaN     2022-08-21      4:23:16
# 1  NaN     2022-08-20     22:56:12
# 2  NaN     2022-08-20      9:05:02
# 3  NaN     2022-08-20      3:52:29
# 4  NaN     2022-08-20      3:47:09

# %%
# Step 3: Data Preprocessing
# Combine all the symptom descriptions into a single string
# Replace 'Symptom_Description' with the actual column name in your dataset
text = " ".join(text for text in df['title'])

# Define stopwords
custom_stopwords = set(stopwords.words('english')).union(STOPWORDS)

# Add more stopwords if necessary
# custom_stopwords.update(['disease', 'symptom', 'patient', 'treatment'])  # Example of adding more stopwords

# %%
# Step 4: Generate the Word Cloud
wordcloud = WordCloud(stopwords=custom_stopwords, background_color='white', max_words=100, width=800, height=400).generate(text)

# %%
# Step 5: Plot the Word Cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Turn off axis
plt.show()

# %% [markdown]
# Add custom stopwords in cell 7 and check the output.What insights can you gain.
